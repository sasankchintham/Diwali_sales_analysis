# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ds=pd.read_excel("D:\Diwali-Sales-Data.xlsx")

# %%
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# ## 1. What is the shape of the dataframe after loading the data?

# %%
ds.shape
# Out:
# (11251, 15)

# %% [markdown]
# ### Findings: The shape of dataset after loading Rows-11251, columns-15

# %% [markdown]
# ## 2. Can you display the first few rows of the dataframe?

# %%
ds.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#            State      Zone       Occupation Product_Category  Orders   Amount  \
# 0    Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1          False  Southern             Govt             Auto       3  23934.0
# 2  Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3      Karnataka  Southern     Construction             Auto       2  23912.0
# 4        Gujarat   Western  Food Processing             Auto       2  23877.0
#
#    Status  unnamed1
# 0     NaN       NaN
# 1     NaN       NaN
# ...

# %% [markdown]
# ### Findings: head() displays the first 5 rows of dataset

# %% [markdown]
# ## 3. What information does the 'info()' function provide about the dataframe?

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Findings: The info() function provides the data types, number of columns and non-null(not missing values), number of rows and columns of entire data set

# %% [markdown]
# ## 4. Why were the 'Status' and 'unnamed1' columns dropped from the dataframe?

# %%
ds.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# ### Findings:In the data dataset if we observe there are no values or data under the 'Status' and 'Unnamed1' columns.So, dropping is the best option.

# %% [markdown]
# ## 5. How were the null values handled in the dataframe?

# %% [markdown]
# #### The null values are the entities where there is no vlaue.
#
# #### First find the null values in the dataset in each column and then fill the value based on the observation of each cloumn.
#
# ##### mean,median,mode are most widely used in filling null values.

# %%
ds.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# Null Values are Present in Amount-12 null values

# %%
ds['Amount']
# Out:
# 0        23952.0
# 1        23934.0
# 2        23924.0
# 3        23912.0
# 4        23877.0
#           ...
# 11246      370.0
# 11247      367.0
# 11248      213.0
# 11249      206.0
# 11250      188.0
# Name: Amount, Length: 11251, dtype: float64

# %%
null_val=ds[ds['Amount'].isnull()]

# %%
print(null_val)
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 7    1002092  Shivangi  P00273442      F       55+   61               0
# 14   1003858      Cano  P00293742      M     46-50   46               1
# 16   1005447       Amy  P00275642      F     46-50   48               1
# 109  1005265    Sakshi  P00296242      F     46-50   48               1
# 111  1005261   Apoorva  P00057942      F     36-45   41               1
# 184  1005538    Kartik  P00269542      F     46-50   49               1
# 293  1000326  Jonathan  P00120542      M     51-55   53               0
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
# 345  1004498   Srishti  P00030842      F     51-55   55               0
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
# ...

# %% [markdown]
# #### Findings: The above is the null values list that is present in the dataset

# %%
auto=ds[ds['Product_Category']=="Auto"]

# %%
auto
# Out:
#       User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0     1002903  Sanskriti  P00125942      F     26-35   28               0
# 1     1000732     Kartik  P00110942      F     26-35   35               1
# 2     1001990      Bindu  P00118542      F     26-35   35               1
# 3     1001425     Sudevi  P00237842      M      0-17   16               0
# 4     1000588       Joni  P00057942      M     26-35   28               1
# ...       ...        ...        ...    ...       ...  ...             ...
# 2460  1001941      Gopal  P00259142      M     36-45   26               1
# 2461  1001202    Diwakar  P00277642      F     36-45   39               0
# 4588  1005642     Eplett  P00057542      F      0-17   13               0
# 4651  1004704    Manshul  P00085242      F     18-25   24               1
# 4687  1000157   Michelle  P00102042      F     36-45   41               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
print(auto['Amount'].mean())
# Out:
# 20191.85556701031

# %%
print(auto['Amount'].mode())
# Out:
# 0    23568.0
# 1    23877.0
# Name: Amount, dtype: float64

# %%
print(auto['Amount'].median())
# Out:
# 19295.0

# %%
ds.loc[(ds['Product_Category']=='Auto')&(ds['Amount'].isnull()),'Amount']=19295.0

# %%
ds.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              9
# dtype: int64

# %% [markdown]
# ### Findings: First 'Auto' dataset is made from the Product_category and then mean,median,mode is found.
# ### Then replaced with the median value

# %%
FS=ds[ds['Product_Category']=='Footwear & Shoes']

# %%
FS
# Out:
#       User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 81    1000154     Shami  P00306042      F     51-55   53               1
# 82    1000749  Flanagan  P00114342      F     36-45   37               1
# 83    1006040      Pond  P00271242      F     26-35   28               1
# 84    1001284   O'Brian  P00157142      M     46-50   50               0
# 85    1004269   Namrata  P00345242      F     36-45   40               0
# ...       ...       ...        ...    ...       ...  ...             ...
# 9460  1000911   Jaydeep  P00101342      M     51-55   55               1
# 9465  1003619  Harrigan  P00246942      F     51-55   51               0
# 9468  1003018      Rhea  P00346042      F     36-45   45               0
# 9474  1002748    Farhat  P00004142      F     26-35   31               0
# 9476  1003403   Abelman  P00022142      F     36-45   42               0
#
#               State      Zone  Occupation  Product_Category  Orders   Amount
# ...

# %%
FS['Amount'].mean()
# Out:
# 14707.468791312558

# %%
FS['Amount'].median()
# Out:
# 16289.0

# %%
FS['Amount'].mode()
# Out:
# 0    16475.0
# Name: Amount, dtype: float64

# %%
ds.loc[(ds['Product_Category']=='Footwear & Shoes') & ds['Amount'].isnull(),'Amount']=16289.0

# %%
ds.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              4
# dtype: int64

# %% [markdown]
# ### Findings: Second 'Footwear & shoes' dataset is made from the Product_category and then mean,median,mode is found.
# ### Then replaced with the median value

# %%
furn=ds[ds['Product_Category']=='Furniture']

# %%
furn
# Out:
#       User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 161   1004016      Dowd  P00123842      M     51-55   51               1
# 165   1002511    Ananya  P00148642      M     26-35   34               0
# 167   1005481      Wale  P00277642      F     46-50   46               0
# 171   1000167    Brooke  P00322142      M     26-35   32               0
# 187   1003081   Kalyani  P00218642      F     26-35   32               0
# ...       ...       ...        ...    ...       ...  ...             ...
# 9285  1001404    Vineet  P00259342      F     51-55   55               0
# 9379  1001421     Fjeld  P00278942      F      0-17   12               0
# 9382  1005973       Tim  P00114942      F      0-17   16               0
# 9443  1005838   Bensley  P00034742      M     46-50   46               0
# 9517  1005493   Stewart  P00052242      M     36-45   45               0
#
#               State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
null_furn=furn[furn['Amount'].isnull()]

# %%
null_furn
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
#
#        State     Zone Occupation Product_Category  Orders  Amount
# 344  Gujarat  Western   Chemical        Furniture       1     NaN

# %%
furn['Amount'].mean()
# Out:
# 15454.69315340909

# %%
furn['Amount'].mode()
# Out:
# 0      8346.0
# 1      8594.0
# 2     12198.0
# 3     12363.0
# 4     12558.0
# 5     12658.0
# 6     12671.0
# 7     12722.0
# 8     15952.0
# 9     15992.0
# 10    16103.0
# 11    16416.0
# 12    16484.0
# 13    16518.0
# 14    16599.0
# 15    16614.0
# 16    16706.0
# 17    19927.0
# 18    20058.0
# 19    20131.0
# 20    20149.0
# 21    20191.0
# 22    20607.0
# Name: Amount, dtype: float64

# %%
furn['Amount'].median()
# Out:
# 16277.5

# %%
ds.loc[(ds['Product_Category']=='Furniture') & ds['Amount'].isnull(),'Amount']=16277.5

# %% [markdown]
# ### Findings: First 'Furniture' dataset is made from the Product_category and then mean,median,mode is found.
# ### Then replaced with the median value

# %%
ds.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              3
# dtype: int64

# %%
food=ds[ds['Product_Category']=='Food']

# %%
food
# Out:
#       User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 437   1001669     George  P00053842      M     26-35   32               0
# 438   1001556     Deanra  P00113942      F     18-25   18               0
# 439   1003615      liebe  P00190942      F     26-35   28               1
# 440   1001943     Phelps  P00028542      F     18-25   23               1
# 441   1004449   Masurkar  P00312842      F     26-35   30               0
# ...       ...        ...        ...    ...       ...  ...             ...
# 9692  1001941      Gopal  P00305042      M     36-45   26               1
# 9693  1001607      Kampe  P00250642      F     46-50   47               1
# 9697  1004311     Laurel  P00282442      F     51-55   53               0
# 9702  1001298  Siddharth  P00106642      F     36-45   36               0
# 9709  1003026  Hendricks  P00084442      M     18-25   22               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
food_null=food[food['Amount'].isnull()]

# %%
food_null
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
#               State     Zone   Occupation Product_Category  Orders  Amount
# 452  Madhya Pradesh  Central  Hospitality             Food       4     NaN
# 464   Uttar Pradesh  Central   Automobile             Food       2     NaN
# 493   Uttar Pradesh  Central    IT Sector             Food       4     NaN

# %%
food['Amount'].mean()
# Out:
# 13628.065662650602

# %%
food['Amount'].median()
# Out:
# 15232.0

# %%
food['Amount'].mode()
# Out:
# 0    11479.0
# 1    11606.0
# 2    11667.0
# 3    11756.0
# 4    12099.0
# 5    15254.0
# 6    15470.0
# 7    15472.0
# Name: Amount, dtype: float64

# %%
ds.loc[(ds['Product_Category']=='Food')&ds['Amount'].isnull(),'Amount']=15232.0

# %% [markdown]
# ### Findings: First 'Food' dataset is made from the Product_category and then mean,median,mode is found.
# ### Then replaced with the median value

# %%
ds.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# # Findings: Finally there are no NULL Values
# ### First there were 12 null values under the 'Amount' column.
# ### Based on the 'Product_Category' the "Amount" column is filled with mean,median and mode of those belonged category inplace of null values.

# %% [markdown]
# ## 6.What was the data type conversion applied to the 'Amount' column?

# %%
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
ds['Amount']
# Out:
# 0        23952.0
# 1        23934.0
# 2        23924.0
# 3        23912.0
# 4        23877.0
#           ...
# 11246      370.0
# 11247      367.0
# 11248      213.0
# 11249      206.0
# 11250      188.0
# Name: Amount, Length: 11251, dtype: float64

# %% [markdown]
# #### Findings:'Amount' category is with float data type.
# ##### As it is already in the float data type there is no need to apply any conversion of data type.

# %% [markdown]
# ## 7. How many unique columns are there in the dataframe?

# %%
ds.columns.nunique()
# Out:
# 13

# %%
ds.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# ### There are 13 unique columns, they are listed above.

# %% [markdown]
# ## 8. What is the new name assigned to the 'Marital_Status' column?

# %%
ds.rename(columns={'Marital_Status':"Married"},inplace=True)

# %%
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Married  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28        0
# 1      1000732       Kartik  P00110942      F     26-35   35        1
# 2      1001990        Bindu  P00118542      F     26-35   35        1
# 3      1001425       Sudevi  P00237842      M      0-17   16        0
# 4      1000588         Joni  P00057942      M     26-35   28        1
# ...        ...          ...        ...    ...       ...  ...      ...
# 11246  1000695      Manning  P00296942      M     18-25   19        1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33        0
# 11248  1001209        Oshin  P00201342      F     36-45   40        0
# 11249  1004023       Noonan  P00059442      M     36-45   37        0
# 11250  1002744      Brumley  P00281742      F     18-25   19        0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %% [markdown]
# ### Findings: The column name "Marital_Status" is named as "Married"

# %% [markdown]
# ## What kind of statistics does the 'describe()' method provide?

# %%
ds.describe()
# Out:
#             User_ID           Age       Married        Orders        Amount
# count  1.125100e+04  11251.000000  11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207      0.420318      2.489290   9461.419956
# std    1.716125e+03     12.754122      0.493632      1.115047   5225.273654
# min    1.000001e+06     12.000000      0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      0.000000      1.500000   5443.500000
# 50%    1.003065e+06     33.000000      0.000000      2.000000   8110.000000
# 75%    1.004430e+06     43.000000      1.000000      3.000000  12691.500000
# max    1.006040e+06     92.000000      1.000000      4.000000  23952.000000

# %% [markdown]
# #### Describe()- It provides the statistical description of numerical Columns(ex: mean,median,mode,std,etc..)

# %% [markdown]
# ##  What specific columns are analyzed using the 'describe()' method?

# %%
ds.describe()
# Out:
#             User_ID           Age       Married        Orders        Amount
# count  1.125100e+04  11251.000000  11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207      0.420318      2.489290   9461.419956
# std    1.716125e+03     12.754122      0.493632      1.115047   5225.273654
# min    1.000001e+06     12.000000      0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      0.000000      1.500000   5443.500000
# 50%    1.003065e+06     33.000000      0.000000      2.000000   8110.000000
# 75%    1.004430e+06     43.000000      1.000000      3.000000  12691.500000
# max    1.006040e+06     92.000000      1.000000      4.000000  23952.000000

# %% [markdown]
# ### Findings: Describe gives the statistics of only those columns that belong to numericals.
# ### As above we can see that there are columns like "Age,orders,amount" etcc which are numeric in nature.

# %% [markdown]
# ## 11. How is the count of each category in the 'Gender' column visualized?

# %% [markdown]
# ### In gender column there are only two categories male and female(M and F).
# ### We can use multiple graphs like pie chart, bar chart to represent the count of these two categories

# %%
ds['Gender']
# Out:
# 0        F
# 1        F
# 2        F
# 3        M
# 4        M
#         ..
# 11246    M
# 11247    M
# 11248    F
# 11249    M
# 11250    F
# Name: Gender, Length: 11251, dtype: object

# %%
male=ds[ds['Gender']=='M']

# %%
mc=male.shape[0]

# %%
mc
# Out:
# 3409

# %%
female=ds[ds['Gender']=='F']

# %%
fc=female.shape[0]

# %%
fc
# Out:
# 7842

# %% [markdown]
# ### male bar chart

# %%
plt.bar('Male', mc, color='blue', width=0.5)
plt.title('Count of Males in Gender Column')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Female bar chart

# %%
plt.bar('Female',fc,color='pink',width=0.5)
plt.title('female count in gender column')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### How is the count of each category in the 'Gender' column visualized?

# %%
plt.bar('Male', mc, color='blue', width=0.4, label='Male')
plt.bar('Female', fc, color='pink', width=0.4, label='Female')

plt.title('Count of Males and Females in Gender Column')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend()
plt.text('Male', mc ,str(mc), fontsize=10, color='black')
plt.text('Female', fc , str(fc),fontsize=10, color='black')
plt.show()

# %% [markdown]
# ### How is the count of each category in the 'Gender' column visualized?

# %% [markdown]
# ### Findings : The above bar graph shows the male and female count from the gender category.
# ### male-3409, female-7842

# %% [markdown]
# ### pie chart

# %%
labels = ['Male', 'Female']
sizes = [mc, fc]
colors = ['blue', 'pink']
plt.pie(sizes,labels=labels,colors=colors)
plt.title('Gender count')
plt.show()

# %% [markdown]
# #### The above is the pie chart representing the genders(blue-male,pink-female)

# %% [markdown]
# ### Findings: By visualizing the we can say that most of the people who are buying on diwali sale belong to female category

# %% [markdown]
# ## 12.What does the bar chart for 'Gender' vs 'Total Amount' convey?

# %%
male
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Married  \
# 3      1001425       Sudevi  P00237842      M      0-17   16        0
# 4      1000588         Joni  P00057942      M     26-35   28        1
# 5      1000588         Joni  P00057942      M     26-35   28        1
# 8      1003224       Kushal  P00205642      M     26-35   35        0
# 10     1003829     Harshita  P00200842      M     26-35   34        0
# ...        ...          ...        ...    ...       ...  ...      ...
# 11243  1005446      Sheetal  P00297742      M     51-55   53        0
# 11244  1005446      Sheetal  P00297742      M     51-55   53        0
# 11246  1000695      Manning  P00296942      M     18-25   19        1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33        0
# 11249  1004023       Noonan  P00059442      M     36-45   37        0
#
#                   State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
m_a=male['Amount'].sum()

# %%
m_a
# Out:
# 31948860.0

# %%
female
# Out:
#        User_ID   Cust_name Product_ID Gender Age Group  Age  Married  \
# 0      1002903   Sanskriti  P00125942      F     26-35   28        0
# 1      1000732      Kartik  P00110942      F     26-35   35        1
# 2      1001990       Bindu  P00118542      F     26-35   35        1
# 6      1001132        Balk  P00018042      F     18-25   25        1
# 7      1002092    Shivangi  P00273442      F       55+   61        0
# ...        ...         ...        ...    ...       ...  ...      ...
# 11241  1003032    Matthias  P00058042      F     26-35   33        0
# 11242  1004344  Hildebrand  P00185442      F     26-35   27        1
# 11245  1004140   Bertelson  P00057442      F     26-35   31        1
# 11248  1001209       Oshin  P00201342      F     36-45   40        0
# 11250  1002744     Brumley  P00281742      F     18-25   19        0
#
#                 State      Zone   Occupation Product_Category  Orders   Amount
# ...

# %%
f_a=female['Amount'].sum()

# %%
f_a
# Out:
# 74501575.93

# %%
plt.bar('male',m_a,color='blue',width=0.4,label='male')
plt.bar('female',f_a,color='pink',width=0.4,label='female')
plt.title('Gender and total amount')
plt.xlabel('gender')
plt.ylabel('total amount in *cr')
plt.show()

# %% [markdown]
# ### Findings: By the above analysis the graphs shows that there are mole female shoppers than the male shoppers.

# %% [markdown]
# ## 13. How is the count of each category in 'Age Group' visualized, considering 'Gender'?

# %%
ds['Age Group'].unique()
# Out:
# array(['26-35', '0-17', '18-25', '55+', '46-50', '51-55', '36-45'],
#       dtype=object)

# %%
grouped_age=ds.groupby(['Age Group','Gender']).size().unstack()

# %%
grouped_age
# Out:
# Gender        F     M
# Age Group
# 0-17        162   134
# 18-25      1305   574
# 26-35      3271  1272
# 36-45      1581   705
# 46-50       696   291
# 51-55       554   278
# 55+         273   155

# %%
grouped_age.plot(kind='bar')
plt.title('age group and gender')
plt.xlabel('agegroup')
plt.ylabel('count')
plt.show()

# %% [markdown]
# #### Findings: Form above visualization we can conclude that the number of females that belong to age category of '26-35' has highest buyers.
# #### lowest sales-men-'0-17'
# #### lowest slaes-female-'0-17'
# #### highest sales-male-'26-35'
# #### highest sales-female-'26-35'
# #### more sales are happening at middle age, 55+ and 0-17 have least sales

# %% [markdown]
# ## 14. What insights can be derived from the 'Total Amount vs Age Group' visualization?

# %%
ds['Age Group'].unique()
# Out:
# array(['26-35', '0-17', '18-25', '55+', '46-50', '51-55', '36-45'],
#       dtype=object)

# %%
age_amt=ds.groupby('Age Group')['Amount'].sum()

# %%
age_amt
# Out:
# Age Group
# 0-17      2699653.00
# 18-25    17240732.00
# 26-35    42644953.44
# 36-45    22191748.49
# 46-50     9279012.00
# 51-55     8294055.00
# 55+       4100282.00
# Name: Amount, dtype: float64

# %%
age_amt.plot(kind='bar')
plt.title('amount vs age group')
plt.xlabel('Age group')
plt.ylabel('amount')
# Out:
# Text(0, 0.5, 'amount')

# %% [markdown]
# #### Findings: The insights that are retreived from the above grpah are the:
# #### age group '0-17' has lowest sales
# #### age group '26.35' has highest sales

# %% [markdown]
# ## 15. What are the total number of orders from the top 10 states?

# %%
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Married  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28        0
# 1      1000732       Kartik  P00110942      F     26-35   35        1
# 2      1001990        Bindu  P00118542      F     26-35   35        1
# 3      1001425       Sudevi  P00237842      M      0-17   16        0
# 4      1000588         Joni  P00057942      M     26-35   28        1
# ...        ...          ...        ...    ...       ...  ...      ...
# 11246  1000695      Manning  P00296942      M     18-25   19        1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33        0
# 11248  1001209        Oshin  P00201342      F     36-45   40        0
# 11249  1004023       Noonan  P00059442      M     36-45   37        0
# 11250  1002744      Brumley  P00281742      F     18-25   19        0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
ds['State'].unique()
# Out:
# array(['Maharashtra', False, 'Uttar Pradesh', 'Karnataka', 'Gujarat',
#        'Himachal Pradesh', 'Delhi', 'Madhya Pradesh', 'Jharkhand',
#        'Kerala', 'Haryana', 'Bihar', 'Rajasthan', 'Uttarakhand',
#        'Telangana', 'Punjab'], dtype=object)

# %%
ds['State'] = ds['State'].replace(False, 'Telangana')

# %%
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Married  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28        0
# 1      1000732       Kartik  P00110942      F     26-35   35        1
# 2      1001990        Bindu  P00118542      F     26-35   35        1
# 3      1001425       Sudevi  P00237842      M      0-17   16        0
# 4      1000588         Joni  P00057942      M     26-35   28        1
# ...        ...          ...        ...    ...       ...  ...      ...
# 11246  1000695      Manning  P00296942      M     18-25   19        1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33        0
# 11248  1001209        Oshin  P00201342      F     36-45   40        0
# 11249  1004023       Noonan  P00059442      M     36-45   37        0
# 11250  1002744      Brumley  P00281742      F     18-25   19        0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
c=ds['State'].value_counts()

# %%
c
# Out:
# State
# Uttar Pradesh       1946
# Maharashtra         1526
# Karnataka           1305
# Delhi               1107
# Telangana            937
# Madhya Pradesh       923
# Himachal Pradesh     608
# Kerala               453
# Haryana              452
# Bihar                434
# Gujarat              429
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Name: count, dtype: int64

# %% [markdown]
# #### The above are the top 10 states with number of orders
# #### Uttar Pradesh has maximum number of orders
# #### Bihar has the minimum number of orders

# %% [markdown]
# ## 16. How is the total amount/sales from the top 10 states visualized?

# %%
amt_state=ds.groupby('State')['Amount'].sum()
#age_amt=ds.groupby('Age Group')['Amount'].sum()

# %%
amt_state
# Out:
# State
# Bihar                4022757.00
# Delhi               11652686.45
# Gujarat              3978648.50
# Haryana              4220175.00
# Himachal Pradesh     4963368.00
# Jharkhand            3026456.00
# Karnataka           13539829.00
# Kerala               3894491.99
# Madhya Pradesh       8135669.00
# Maharashtra         14446838.00
# Punjab               1525800.00
# Rajasthan            1909409.00
# Telangana            9207931.99
# Uttar Pradesh       19405432.00
# Uttarakhand          2520944.00
# Name: Amount, dtype: float64

# %%
amt_state.plot(kind='bar')
plt.title('total amount/sales from the top 10 states')
plt.xlabel('State')
plt.ylabel('Amount in *cr')
plt.show()

# %% [markdown]
# ## 17. How is the count of each category in 'Marital_Status' visualized?

# %%
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Married  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28        0
# 1      1000732       Kartik  P00110942      F     26-35   35        1
# 2      1001990        Bindu  P00118542      F     26-35   35        1
# 3      1001425       Sudevi  P00237842      M      0-17   16        0
# 4      1000588         Joni  P00057942      M     26-35   28        1
# ...        ...          ...        ...    ...       ...  ...      ...
# 11246  1000695      Manning  P00296942      M     18-25   19        1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33        0
# 11248  1001209        Oshin  P00201342      F     36-45   40        0
# 11249  1004023       Noonan  P00059442      M     36-45   37        0
# 11250  1002744      Brumley  P00281742      F     18-25   19        0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
ds['Married'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
unmarried_count=ds[ds['Married']==0]

# %%
uc=unmarried_count['Married'].count()

# %%
uc
# Out:
# 6522

# %%
married_count=ds[ds['Married']==1]

# %%
mc=married_count['Married'].count()

# %%
mc
# Out:
# 4729

# %%
plt.bar('unmarried',uc,color='green',width=0.4)
plt.bar('married,',mc,color='red',width=0.4)
plt.xlabel('Category')
plt.ylabel('count')
plt.title('marital status count')
plt.show()

# %% [markdown]
# ### 18. What does the bar chart for 'Marital_Status' vs 'Amount' convey, considering 'Gender'?

# %%
grouped = ds.groupby(['Married', 'Gender'])['Amount'].mean().unstack()

# %%
grouped.plot(kind='bar', figsize=(10, 6), color=['blue', 'pink'])
plt.xlabel('Marital Status')
plt.ylabel('Average Amount')
plt.title('Average Amount by Marital Status and Gender')
plt.xticks(rotation=0)
plt.legend(title='Gender')

# %% [markdown]
# #### by seeing above graphs we can say that there is not much difference between the married and unmarried based on gender.
# #### both shows same type of sales

# %% [markdown]
# ### 19. How is the count of each category in 'Occupation' visualized?

# %%
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Married  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28        0
# 1      1000732       Kartik  P00110942      F     26-35   35        1
# 2      1001990        Bindu  P00118542      F     26-35   35        1
# 3      1001425       Sudevi  P00237842      M      0-17   16        0
# 4      1000588         Joni  P00057942      M     26-35   28        1
# ...        ...          ...        ...    ...       ...  ...      ...
# 11246  1000695      Manning  P00296942      M     18-25   19        1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33        0
# 11248  1001209        Oshin  P00201342      F     36-45   40        0
# 11249  1004023       Noonan  P00059442      M     36-45   37        0
# 11250  1002744      Brumley  P00281742      F     18-25   19        0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
ds['Occupation'].unique()
# Out:
# array(['Healthcare', 'Govt', 'Automobile', 'Construction',
#        'Food Processing', 'Lawyer', 'IT Sector', 'Media', 'Banking',
#        'Retail', 'Hospitality', 'Aviation', 'Agriculture', 'Textile',
#        'Chemical'], dtype=object)

# %%
cnt_oc=ds['Occupation'].value_counts()

# %%
cnt_oc
# Out:
# Occupation
# IT Sector          1588
# Healthcare         1408
# Aviation           1310
# Banking            1139
# Govt                854
# Hospitality         705
# Media               637
# Automobile          566
# Chemical            542
# Lawyer              531
# Retail              501
# Food Processing     423
# Construction        414
# Textile             350
# Agriculture         283
# Name: count, dtype: int64

# %%
cnt_oc.plot(kind='bar')
plt.xlabel('Occupation')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.title('Occupation Count')
plt.show()

# %% [markdown]
# #### Findings: The above bar chart shows the count of all different occupations under 'Occupation' Attribute.
# #### 1.IT Sector -highest- Means they are the highest number of buyers in diwali sale
# #### 2.Agriculture- least - means they are the least number of buyers in diwali sale

# %% [markdown]
# ## 20. How is the count of each category in 'Product_Category' visualized?

# %%
ds['Product_Category']
# Out:
# 0              Auto
# 1              Auto
# 2              Auto
# 3              Auto
# 4              Auto
#             ...
# 11246        Office
# 11247    Veterinary
# 11248        Office
# 11249        Office
# 11250        Office
# Name: Product_Category, Length: 11251, dtype: object

# %%
pc=ds['Product_Category'].value_counts()

# %%
pc
# Out:
# Product_Category
# Clothing & Apparel       2655
# Food                     2493
# Electronics & Gadgets    2087
# Footwear & Shoes         1064
# Household items           520
# Beauty                    422
# Games & Toys              386
# Sports Products           356
# Furniture                 353
# Pet Care                  212
# Office                    113
# Stationery                112
# Books                     103
# Auto                      100
# Decor                      96
# Veterinary                 81
# Tupperware                 72
# Hand & Power Tools         26
# Name: count, dtype: int64

# %%
pc.plot(kind='bar')
plt.xlabel('Product Category')
plt.ylabel('Count')
plt.title('Product Category count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Findings:
# #### 1.The Diwali sale has more number of sales in clothing and Apparel, food section.
# #### 2.Lowest is for the Hand and power tools
# #### 3.Top sold Categories:clothing,food,electronics, footwear
# #### 4.Rest all categories seems to be least sold

# %% [markdown]
# ### 21. What are the top 10 product categories by total sales amount?

# %%
top_10=ds.groupby('Product_Category')['Amount'].sum()

# %%
top_10
# Out:
# Product_Category
# Auto                      2016494.99
# Beauty                    1959484.00
# Books                     1061478.00
# Clothing & Apparel       16495019.00
# Decor                      730360.00
# Electronics & Gadgets    15643846.00
# Food                     33979579.50
# Footwear & Shoes         15656654.45
# Furniture                 5456329.49
# Games & Toys              4331694.00
# Hand & Power Tools         405618.00
# Household items           1569337.00
# Office                      81936.00
# Pet Care                   482277.00
# Sports Products           3635933.00
# Stationery                1676051.50
# Tupperware                1155642.00
# Veterinary                 112702.00
# Name: Amount, dtype: float64

# %%
top_10.plot(kind='bar')
plt.xlabel('Product category')
plt.ylabel('Amount in *cr')
plt.title('Top category sold by total amount')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Findings: Food has highest in terms of total amount in diwali sale
# #### by the graph we can see top 10

# %% [markdown]
# ### 22. What are the top 10 most sold products?

# %%
sp=ds.groupby('Product_Category')['Orders'].sum()

# %%
sp
# Out:
# Product_Category
# Auto                      246
# Beauty                   1086
# Books                     245
# Clothing & Apparel       6634
# Decor                     235
# Electronics & Gadgets    5226
# Food                     6120
# Footwear & Shoes         2654
# Furniture                 890
# Games & Toys              940
# Hand & Power Tools         80
# Household items          1331
# Office                    261
# Pet Care                  536
# Sports Products           870
# Stationery                281
# Tupperware                166
# Veterinary                206
# Name: Orders, dtype: int64

# %% [markdown]
# #### 23. Can you display the top 10 most sold products in a bar chart?

# %%
sp.plot(kind='bar')
plt.xlabel('Product Category')
plt.ylabel('No.of sold items')
plt.title('most sold products')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Findings: The highest sold products are from clothing and apparel.

# %% [markdown]
# ### 24. How is the total number of orders calculated for each product ID?

# %%
total_orders=ds.groupby('Product_ID')['Orders'].sum()

# %%
pd.set_option('display.max_rows', 3000)
total_orders
# Out:
# Product_ID
# P00000142     57
# P00000242     15
# P00000342     16
# P00000442      1
# P00000542      6
# P00000642     30
# P00000742     19
# P00000842      4
# P00001042     19
# P00001142     16
# P00001342      3
# P00001442     15
# P00001542      3
# P00001642     10
# P00001742     22
# P00001842      9
# P00001942     15
# P00002042      7
# P00002142     17
# P00002242     19
# P00002342      3
# P00002442     10
# P00002542     19
# P00002642      2
# P00002742      8
# P00002842      7
# P00002942     24
# P00003042      1
# P00003142      4
# P00003242     51
# P00003442     57
# P00003542      3
# P00003642     30
# P00003942     45
# P00004142      1
# P00004242      5
# P00004342      5
# P00004442      6
# P00004542      5
# P00004642      7
# P00004742     32
# P00004842      6
# P00005042     33
# P00005142     13
# P00005642      7
# P00005742     11
# P00005942      6
# P00006042      1
# P00006142     16
# P00006242      1
# P00006442      3
# ...

# %% [markdown]
# #### Findings: The above are the total no.of orders calculated for each productID.

# %% [markdown]
# ### 25. What insights can be derived from the visualization of the top 10 most sold products?

# %%
sp.plot(kind='bar')
plt.xlabel('Product Category')
plt.ylabel('No.of sold items')
plt.title('most sold products')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Findings and Insights: The most sold products in Diwali sales are:
# ####      Clothing and Apparel
# ####      Food
# ####      Electronics and gadgets
# #### Least sold are:
# ####      hand and power
# ####      books
# ####      Auto
# ####      Tupperware
